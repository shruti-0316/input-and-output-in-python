# %% [markdown]
# **1.Python get user input with a message.**

# %%
# Taking input from the user
name = input("Enter your name: ")

# Output
print("Hello, " + name)
print(type(name))
# Out:
# Enter your name: shruti
# Hello, shruti
# <class 'str'>

# %% [markdown]
# **2.Integer input in Python .**

# %%
# Taking input from the user as integer
num = int(input("Enter a number: "))

add = num + 1

# Output
print(add)
# Out:
# Enter a number: 3
# 4

# %% [markdown]
# **3.Python Print Output.**

# %%
# Python program to demonstrate
# print() method
print("GFG")

# code for disabling the softspace feature
print('G', 'F', 'G')
# Out:
# GFG
# G F G

# %% [markdown]
# **4.Python Print output with custom sep and end parameter.**

# %%
# Python program to demonstrate
# print() method
print("gmail", end = "@")

# code for disabling the softspace feature
print('G', 'F', 'G', sep="#")
# Out:
# gmail@G#F#G

# %% [markdown]
# **5.Python String formatting using F string.**

# %%
# Declaring a variable
name = "Shruti"

# Output
print(f'Hello {name}! How are you?')
# Out:
# Hello Shruti! How are you?

# %% [markdown]
# **6.Python string formatting using format() function.**

# %%
# Initializing variables
a = 20
b = 10
# addition
sum = a + b
# subtraction
sub = a- b

# Output
print('The value of a is {} and b is {}'.format(a,b))

print('{2} is the sum of {0} and {1}'.format(a,b,sum))

print('{sub_value} is the subtraction of {value_a} and {value_b}'.format(value_a = a ,
																		value_b = b,
																		sub_value = sub))
# Out:
# The value of a is 20 and b is 10
# 30 is the sum of 20 and 10
# 10 is the subtraction of 20 and 10
